# %% [markdown]
# <a href="https://colab.research.google.com/github/KABANYANA/NLP_Fellowsip/blob/main/EasyNMT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U easynmt

# %%
from easynmt import EasyNMT

# %%
model = EasyNMT('opus-mt')
# Out:
# 11.9kB [00:00, 2.20MB/s]

# %%
sentences = [
    'Jesus is alive',
    'Hands on projects is our priority',
    "I don't have anything",
    'it is a rainy day'
]

# %%
translations = model.translate(sentences, target_lang='fr')
# Out:
# 100%|██████████| 938k/938k [00:00<00:00, 2.02MB/s]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Downloading:   0%|          | 0.00/778k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Downloading:   0%|          | 0.00/301M [00:00<?, ?B/s]
# ...

# %%
sentences
# Out:
# ['Jesus is alive',
#  'Hands on projects is our priority',
#  "I don't have anything",
#  'it is a rainy day']

# %%
translations
# Out:
# ['Jésus est vivant',
#  'Mains sur les projets est notre priorité',
#  "Je n'ai rien.",
#  "C'est un jour pluvieux"]

# %%
translations = model.translate(sentences, target_lang='sw')
# Out:
# Downloading:   0%|          | 0.00/821k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/813k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Downloading:   0%|          | 0.00/300M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1364: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 512 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,

# %%
translations
# Out:
# ['Yesu yu hai',
#  'Ni jambo la kwanza kabisa kwetu kuwa na mikono kwenye miradi',
#  'Sina chochote',
#  'Ni siku yenye mvua']

# %%
translations = model.translate(sentences, target_lang='rw')
# Out:
# Downloading:   0%|          | 0.00/812k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/810k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Downloading:   0%|          | 0.00/303M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1364: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 512 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,

# %%
translations
# Out:
# ['Yesu ni muzima',
#  'Ibintu tugomba gushyira mu mwanya wa mbere ni byo dushyira mu mwanya wa mbere',
#  '........',
#  "Ni umunsi w'imvura"]

# %%
translations = model.translate(sentences, target_lang='zh')
# Out:
# Downloading:   0%|          | 0.00/806k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/805k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Downloading:   0%|          | 0.00/312M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1364: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 512 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,

# %%
translations
# Out:
# ['耶稣还活着', '手放在项目上是我们的优先事项', '我什么都没有', '确是有雨的日子,']

# %%
import json

# %%
with open('/content/lang.json','r+')as file_lang:
  content = file_lang.read()

# %%
languages_json = json.loads(content)

# %%
languages_json[1]
# Out:
# {'code': 'aa', 'name': 'Afar'}

# %%
languages_json[1]['code']
# Out:
# 'aa'

# %%
len(languages_json)
# Out:
# 184

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
rw_sentences = [
    'Jesus is alive',
    'Hands on projects is our priority',
    "I don't have anything",
    'it is a rainy day'
]

# %%
df['english'] = sentences

# %%
df
# Out:
#                              english
# 0                     Jesus is alive
# 1  Hands on projects is our priority
# 2              I don't have anything
# 3                  it is a rainy day

# %%
for language in languages_json[80:100]:
  code = language['code']
  name = language['name']
  try:
   df[name] = model.translate(df['english'], source_lang='en', target_lang=code)
  except:
    pass
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1364: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 512 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,

# %%
df
# Out:
#                              english  \
# 0                     Jesus is alive
# 1  Hands on projects is our priority
# 2              I don't have anything
# 3                  it is a rainy day
#
#                                                   rw  \
# 0                                     Yesu ni muzima
# 1  Ibintu tugomba gushyira mu mwanya wa mbere ni ...
# 2                                           ........
# 3                                 Ni umunsi w'imvura
#
#                                                   kg  \
# 0                               Yezu kele na luzingu
# 1  Mbongo ya kisalu kele mambu ya kuluta mfunu yi...
# 2                      Mono kele ve ata ti kima mosi
# 3                      Yo kele kilumbu mosi ya mvula
#
#                                                   kj  \
# 0                               Jesus oku na omwenyo
# 1  Ohai tu kwafele tu kale twa pitifa komesho oil...
# 2                                      Kandi na sha.
# ...
